# %%
import matplotlib.pyplot as plt
import dill
import main

name = input('Desired file name identification?\t')
with open( name + '_fixrhoswarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    bird_sim1 = dill.load(pickle_in)
name = input('Desired file name identification?\t')
with open( name + '_fixrhoswarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    bird_sim2 = dill.load(pickle_in)
name = input('Desired file name identification?\t')
with open( name + '_fixrhoswarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    bird_sim3 = dill.load(pickle_in)
#name = input('Desired file name identification?\t')
#with open( name + '_fixrhoswarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    #bird_sim4 = dill.load(pickle_in)    
#name = input('Desired file name identification?\t')
#with open( name + '_pickle_param_swarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    #bird_sim4 = dill.load(pickle_in)
# Out:
# Desired file name identification?	PL_etavar2pi_N40
# Desired file name identification?	PL_etavar2pi_N100
# Desired file name identification?	PL_etavar2pi_N400

# %% [markdown]
# # mean v_a vs noise

# %%
# NOTICE: input is an array [mean_v_a,rho, eta]
def plot_va_eta(eta_matrix, shape, color, labels):
    # Plot mean order parameter as a function of density when noise is fixed
    plt.title("Order Parameter vs Noise")
    plt.xlabel("η")
    plt.ylabel("$v_a$")
    plt.plot(eta_matrix[:, 2], eta_matrix[:, 0], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()


plot_va_eta(bird_sim1.eta_matrix, 's','#355070','N = 40') 
plot_va_eta(bird_sim2.eta_matrix, 'x','#6d597a','N = 100')
plot_va_eta(bird_sim3.eta_matrix,'+' ,'#b56576', 'N = 400')
#plot_va_eta(bird_sim4.eta_matrix,'^' ,'#214e34', 'N = 1000')
#plot_va_eta(bird_sim4.eta_matrix,'d' ,'#eaac8b', 'N = 4000')
plt.show()

# %% [markdown]
# # mean v_a vs density

# %%
import numpy as np

def plot_va_N(N_matrix, shape, color, labels):
    # Plot mean order parameter as a function of density when noise is fixed
    plt.title("Order Parameter vs Density")
    plt.xlabel("ρ")
    plt.ylabel("$v_a$")
    plt.plot(N_matrix[:, 1], N_matrix[:, 0], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()


#eta = 2 for 300 steps  
N_matrix_1 = np.array([[0.43953478, 0.025     , 2.        ],
       [0.66786584, 0.005     , 2.        ],
       [0.36445307, 0.0075    , 2.        ],
       [0.5457661 , 0.01      , 2.        ],
       [0.31941061, 0.0125    , 2.        ],
       [0.59985402, 0.015     , 2.        ],
       [0.43012782, 0.0175    , 2.        ],
       [0.33265567, 0.02      , 2.        ],
       [0.38297684, 0.0225    , 2.        ],
       [0.19595999, 0.0275    , 2.        ],
       [0.2946972 , 0.0325    , 2.        ],
       [0.37476674, 0.035     , 2.        ],
       [0.22761456, 0.0425    , 2.        ],
       [0.22363535, 0.0475    , 2.        ],
       [0.24952907, 0.055     , 2.        ],
       [0.34461954, 0.0625    , 2.        ],
       [0.30021195, 0.0725    , 2.        ],
       [0.30720823, 0.0825    , 2.        ],
       [0.19487452, 0.095     , 2.        ],
       [0.19628595, 0.1075    , 2.        ],
       [0.25521034, 0.1225    , 2.        ],
       [0.17056496, 0.14      , 2.        ],
       [0.15731379, 0.1625    , 2.        ],
       [0.30490762, 0.185     , 2.        ],
       [0.30849176, 0.21      , 2.        ],
       [0.29355554, 0.24      , 2.        ],
       [0.34493467, 0.275     , 2.        ],
       [0.54392469, 0.3125    , 2.        ],
       [0.35076402, 0.3575    , 2.        ],
       [0.42121856, 0.41      , 2.        ],
       [0.73258791, 0.4675    , 2.        ],
       [0.41118935, 0.5325    , 2.        ],
       [0.69836344, 0.6075    , 2.        ],
       [0.69764075, 0.6925    , 2.        ],
       [0.71436661, 0.79      , 2.        ],
       [0.76548634, 0.9025    , 2.        ],
       [0.73238166, 1.03      , 2.        ],
       [0.73441277, 1.175     , 2.        ],
       [0.76222267, 1.34      , 2.        ],
       [0.77279139, 1.53      , 2.        ],
       [0.7930463 , 1.745     , 2.        ],
       [0.7849341 , 1.99      , 2.        ],
       [0.78638454, 2.27      , 2.        ],
       [0.8024723 , 2.5875    , 2.        ],
       [0.79627514, 2.9525    , 2.        ],
       [0.81669401, 3.3675    , 2.        ],
       [0.81673131, 3.8425    , 2.        ],
       [0.82074947, 4.3825    , 2.        ],
       [0.8095616 , 4.9975    , 2.        ]])
    

#eta = 2.5 for 300 steps
N_matrix_2 = np.array([[ 0.60248114,  0.025     ,  2.5       ],
       [ 0.60248114,  0.025     ,  2.5       ],
       [ 0.53009132,  0.55      ,  2.5       ],
       [ 0.60430284,  1.075     ,  2.5       ],
       [ 0.66044119,  1.6       ,  2.5       ],
       [ 0.67235061,  2.125     ,  2.5       ],
       [ 0.69147836,  2.65      ,  2.5       ],
       [ 0.69930134,  3.175     ,  2.5       ],
       [ 0.70295575,  3.7       ,  2.5       ],
       [ 0.67523804,  4.225     ,  2.5       ],
       [ 0.62221646,  4.75      ,  2.5       ],
       [ 0.69084484,  5.275     ,  2.5       ],
       [ 0.69400511,  5.8       ,  2.5       ],
       [ 0.67926645,  6.325     ,  2.5       ],
       [ 0.71838655,  6.85      ,  2.5       ],
       [ 0.70514094,  7.375     ,  2.5       ],
       [ 0.69987428,  7.9       ,  2.5       ],
       [ 0.70756153,  8.425     ,  2.5       ],
       [ 0.68284171,  8.95      ,  2.5       ],
       [ 0.69713429,  9.475     ,  2.5       ],
       [ 0.67067886, 10.        ,  2.5       ]])
    
plot_va_N(N_matrix_1, 's','#355070','η = 2') 
#plot_va_N(N_matrix_2, 'x','#eaac8b','η = 2.5') 
plt.show()

# %% [markdown]
# # v_a vs time for N = 40 with various noise

# %%
import matplotlib.pyplot as plt
import dill
import numpy as np

name = input('Desired file name identification?\t')
with open( name + '_fixrhoeta_swarm.csv',"rb") as pickle_in:  # "rb" because we want to read in binary mode
    bird_sim1 = dill.load(pickle_in)

# %%
import numpy as np
def plot_va_t(va_matrix, shape, color, labels, index):
    # Plot order parameter as a function of time for two systems: one reachs phase transition and one does not
    plt.title("Evolution of Order Parameter")
    plt.xlabel("t")
    plt.ylabel("$v_a$")
    plt.plot(np.arange(0, len(va_matrix[index]), 1), va_matrix[index], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()
      
plot_va_t(bird_sim1.va_matrix, 'o','#b68cb8','N = 40 , η = 0', 1) 
plot_va_t(bird_sim1.va_matrix, 's','#314cb6','N = 40, η = 3',30)
plot_va_t(bird_sim1.va_matrix, '^','#b33951','N = 40, η = 5', -1)
print(bird_sim1.eta_matrix[8]) 
# i just tried some values to get three different plots and 8 seemd good but if you dnt want it we can delete it
plt.show()
# Out:
# [0.9726209  4.16233091 0.81290323]

# %%
def plot_va_t(va_matrix, shape, color, labels, index):
    # Plot order parameter as a function of time for two systems: one reachs phase transition and one does not
    plt.title("Evolution of Order Parameter")
    plt.xlabel("t")
    plt.ylabel("$v_a$")
    plt.plot(np.arange(0, len(va_matrix[index]), 1), va_matrix[index], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()
      
plot_va_t(bird_sim2.va_matrix, 'o','#b68cb8','N = 100 , η = 0', 1) 
plot_va_t(bird_sim2.va_matrix, 's','#314cb6','N = 100, η = 3',30)
plot_va_t(bird_sim2.va_matrix, '^','#b33951','N = 100, η = 5', -1)
print(bird_sim1.eta_matrix[8]) 
# i just tried some values to get three different plots and 8 seemd good but if you dnt want it we can delete it
plt.show()
# Out:
# [0.9726209  4.16233091 0.81290323]

# %%
def plot_va_t(va_matrix, shape, color, labels, index):
    # Plot order parameter as a function of time for two systems: one reachs phase transition and one does not
    plt.title("Evolution of Order Parameter")
    plt.xlabel("t")
    plt.ylabel("$v_a$")
    plt.plot(np.arange(0, len(va_matrix[index]), 1), va_matrix[index], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()
      
plot_va_t(bird_sim3.va_matrix, 'o','#b68cb8','N = 400 , η = 0', 1) 
plot_va_t(bird_sim3.va_matrix, 's','#314cb6','N = 400, η = 3',30)
plot_va_t(bird_sim3.va_matrix, '^','#b33951','N = 400, η = 5', -1)
print(bird_sim1.eta_matrix[8]) 
# i just tried some values to get three different plots and 8 seemd good but if you dnt want it we can delete it
plt.show()
# Out:
# [0.9726209  4.16233091 0.81290323]

# %%
def plot_va_t(va_matrix, shape, color, labels, index):
    # Plot order parameter as a function of time for two systems: one reachs phase transition and one does not
    plt.title("Evolution of Order Parameter")
    plt.xlabel("t")
    plt.ylabel("$v_a$")
    plt.plot(np.arange(0, len(va_matrix[index]), 1), va_matrix[index], shape, markerfacecolor='none', markeredgecolor=color, label=labels)
    plt.legend()
      
plot_va_t(bird_sim4.va_matrix, 'o','#b68cb8','N = 400 , η = 0', 1) 
plot_va_t(bird_sim4.va_matrix, 's','#314cb6','N = 400, η = 3',30)
plot_va_t(bird_sim4.va_matrix, '^','#b33951','N = 400, η = 5', -1)
print(bird_sim1.eta_matrix[8]) 
# i just tried some values to get three different plots and 8 seemd good but if you dnt want it we can delete it
plt.show()
# Out:
# [0.97240349 4.16233091 0.81632653]
